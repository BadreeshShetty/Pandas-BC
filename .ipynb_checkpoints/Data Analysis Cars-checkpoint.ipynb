# %% [markdown]
# ###  Importing and Inspecting your own Dataset

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %% [markdown]
# #### Details on the Columns:
#
# - __mpg__: Measures __fuel efficiency__ in terms of miles per gallon. __Higher mpg__ means __higher efficiency__
# - __cylinders__: Number of cylinders in the car
# - __displacement__: Technical feature (engine)
# - __horsepower__: Unit of measurement for engine power
# - __weight__: weight in lbs
# - __acceleration__: time to accelerate from 0 to 60 mph (sec.)
# - __model_year__: self explanatory
# - __origin__: origin of the manufacturer/car
# - __name__: model name

# %% [markdown]
# __First 10 Rows__ of cars

# %%
cars.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %% [markdown]
# __Last 5 Rows__

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa   chevrolet s-10

# %% [markdown]
# __Meta information__

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# We have 6 missing/NaN Values in the column ... horsepower

# %% [markdown]
# __Summary statistics__ on cars

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Maximum value in the column horsepower is ... 230!

# %% [markdown]
# ### Indexing and Slicing

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.name
# Out:
# 0              chevrolet chevelle malibu
# 1                      buick skylark 320
# 2                     plymouth satellite
# 3                          amc rebel sst
# 4                            ford torino
# 5                       ford galaxie 500
# 6                       chevrolet impala
# 7                      plymouth fury iii
# 8                       pontiac catalina
# 9                     amc ambassador dpl
# 10                   dodge challenger se
# 11                    plymouth 'cuda 340
# 12                 chevrolet monte carlo
# 13               buick estate wagon (sw)
# 14                 toyota corona mark ii
# 15                       plymouth duster
# 16                            amc hornet
# 17                         ford maverick
# 18                          datsun pl510
# 19                  vw 1131 deluxe sedan
# 20                           peugeot 504
# 21                           audi 100 ls
# 22                              saab 99e
# ...

# %% [markdown]
# __Second alternative__ to select the column __"name"__

# %%
cars["name"]
# Out:
# 0              chevrolet chevelle malibu
# 1                      buick skylark 320
# 2                     plymouth satellite
# 3                          amc rebel sst
# 4                            ford torino
# 5                       ford galaxie 500
# 6                       chevrolet impala
# 7                      plymouth fury iii
# 8                       pontiac catalina
# 9                     amc ambassador dpl
# 10                   dodge challenger se
# 11                    plymouth 'cuda 340
# 12                 chevrolet monte carlo
# 13               buick estate wagon (sw)
# 14                 toyota corona mark ii
# 15                       plymouth duster
# 16                            amc hornet
# 17                         ford maverick
# 18                          datsun pl510
# 19                  vw 1131 deluxe sedan
# 20                           peugeot 504
# 21                           audi 100 ls
# 22                              saab 99e
# ...

# %% [markdown]
# __Select__ the car at __index position 100__

# %%
cars.iloc[100]
# Out:
# mpg                        18
# cylinders                   6
# displacement              250
# horsepower                 88
# weight                   3021
# acceleration             16.5
# model_year                 73
# origin                    usa
# name            ford maverick
# Name: 100, dtype: object

# %% [markdown]
# The car has ... 6 cylinders!

# %% [markdown]
# Select the car at __index position 200__ with the __iloc__ and column name

# %%
cars.iloc[200, 8]
# Out:
# 'ford granada ghia'

# %% [markdown]
# It´s a ... ford granada ghia!

# %% [markdown]
# __Last 10 rows__ and the columns __mpg, horsepower, origin__ and __name__

# %%
cars.iloc[-10:, [0, 3, 7, 8]]
# Out:
#       mpg  horsepower  origin                        name
# 388  26.0        92.0     usa  chrysler lebaron medallion
# 389  22.0       112.0     usa              ford granada l
# 390  32.0        96.0   japan            toyota celica gt
# 391  36.0        84.0     usa           dodge charger 2.2
# 392  27.0        90.0     usa            chevrolet camaro
# 393  27.0        86.0     usa             ford mustang gl
# 394  44.0        52.0  europe                   vw pickup
# 395  32.0        84.0     usa               dodge rampage
# 396  28.0        79.0     usa                 ford ranger
# 397  31.0        82.0     usa              chevrolet s-10

# %% [markdown]
# The mpg is ... 44.0!

# %% [markdown]
# __Import__ the __Cars Dataset__ and set the column __"name"__ as the __index__

# %%
cars = pd.read_csv("cars.csv", index_col = "name")

# %%
cars.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, chevrolet chevelle malibu to chevrolet s-10
# Data columns (total 8 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 28.0+ KB

# %% [markdown]
# Index of the DataFrame by calling the __index__

# %%
cars.index
# Out:
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevrolet s-10'],
#       dtype='object', name='name', length=398)

# %% [markdown]
# __Row__ with the index label __"ford ranger"__

# %%
cars.loc["ford ranger"]
# Out:
# mpg               28
# cylinders          4
# displacement     120
# horsepower        79
# weight          2625
# acceleration    18.6
# model_year        82
# origin           usa
# Name: ford ranger, dtype: object

# %% [markdown]
# The weight is ... 2625!

# %% [markdown]
#  __Row__ with the index label __"ford torino"__ and only the columns __"model_year"__ and __"origin"__

# %%
cars.loc["ford torino", ["model_year", "origin"]]
# Out:
# model_year     70
# origin        usa
# Name: ford torino, dtype: object

# %% [markdown]
# __"mpg"__ and __"weight"__

# %%
cars.loc[:, ["mpg", "weight"]]
# Out:
#                                     mpg  weight
# name
# chevrolet chevelle malibu          18.0    3504
# buick skylark 320                  15.0    3693
# plymouth satellite                 18.0    3436
# amc rebel sst                      16.0    3433
# ford torino                        17.0    3449
# ford galaxie 500                   15.0    4341
# chevrolet impala                   14.0    4354
# plymouth fury iii                  14.0    4312
# pontiac catalina                   14.0    4425
# amc ambassador dpl                 15.0    3850
# dodge challenger se                15.0    3563
# plymouth 'cuda 340                 14.0    3609
# chevrolet monte carlo              15.0    3761
# buick estate wagon (sw)            14.0    3086
# toyota corona mark ii              24.0    2372
# plymouth duster                    22.0    2833
# amc hornet                         18.0    2774
# ford maverick                      21.0    2587
# ...

# %% [markdown]
# ### Analyzing Columns / Pandas Series

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# Numerical column __"mpg"__,__copy__ and __save__ the column/Pandas Series in the variable __mpg__

# %%
mpg = cars.mpg.copy()

# %%
mpg.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %% [markdown]
# __Summary statistics__ on the Series __mpg__

# %%
mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %% [markdown]
# The mpg of the least fuel efficient car is ... 9.0 miles per gallon!

# %% [markdown]
# __Maximum Value__ in the Series __mpg__

# %%
mpg.max()
# Out:
# 46.6

# %% [markdown]
# The most fuel efficient car has a mpg of... 46.6!

# %% [markdown]
# __Frequency Counts__ of all unique __values__ in the Series __mpg__

# %%
mpg.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
# 16.0    13
# 19.0    12
# 24.0    11
# 25.0    11
# 28.0    10
# 22.0    10
# 23.0    10
# 20.0     9
# 27.0     9
# 29.0     8
# 21.0     8
# 30.0     7
# 31.0     7
# 17.0     7
# 12.0     6
# 36.0     6
# 32.0     6
# 17.5     5
# 15.5     5
# 11.0     4
# 38.0     4
# 20.2     4
# 21.5     3
# 33.0     3
# 18.5     3
#         ..
# 20.8     1
# 23.6     1
# 30.9     1
# 43.4     1
# 39.1     1
# 40.9     1
# 20.3     1
# 34.7     1
# 32.9     1
# 22.3     1
# 46.6     1
# 32.2     1
# 26.8     1
# 19.1     1
# 27.5     1
# 19.9     1
# 41.5     1
# 31.6     1
# 35.7     1
# 23.5     1
# 39.0     1
# 25.1     1
# 32.8     1
# 44.0     1
# 28.8     1
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: mpg, Length: 129, dtype: int64

# %% [markdown]
# The most frequent value is ... 13.0!

# %% [markdown]
# __Relative frequencies__ in the Series __mpg__

# %%
mpg.value_counts(normalize = True)
# Out:
# 13.0    0.050251
# 14.0    0.047739
# 18.0    0.042714
# 15.0    0.040201
# 26.0    0.035176
# 16.0    0.032663
# 19.0    0.030151
# 24.0    0.027638
# 25.0    0.027638
# 28.0    0.025126
# 22.0    0.025126
# 23.0    0.025126
# 20.0    0.022613
# 27.0    0.022613
# 29.0    0.020101
# 21.0    0.020101
# 30.0    0.017588
# 31.0    0.017588
# 17.0    0.017588
# 12.0    0.015075
# 36.0    0.015075
# 32.0    0.015075
# 17.5    0.012563
# 15.5    0.012563
# 11.0    0.010050
# 38.0    0.010050
# 20.2    0.010050
# 21.5    0.007538
# 33.0    0.007538
# 18.5    0.007538
#           ...
# 20.8    0.002513
# 23.6    0.002513
# 30.9    0.002513
# 43.4    0.002513
# 39.1    0.002513
# 40.9    0.002513
# 20.3    0.002513
# 34.7    0.002513
# 32.9    0.002513
# 22.3    0.002513
# 46.6    0.002513
# 32.2    0.002513
# 26.8    0.002513
# 19.1    0.002513
# 27.5    0.002513
# 19.9    0.002513
# 41.5    0.002513
# 31.6    0.002513
# 35.7    0.002513
# 23.5    0.002513
# 39.0    0.002513
# ...

# %% [markdown]
# The relative frequency of 13.0 is ... 0.050251!

# %% [markdown]
# __Sort__ the Series __mpg__ from __low to high__

# %%
mpg.sort_values()
# Out:
# 28      9.0
# 25     10.0
# 26     10.0
# 103    11.0
# 124    11.0
# 27     11.0
# 67     11.0
# 95     12.0
# 104    12.0
# 90     12.0
# 106    12.0
# 42     12.0
# 69     12.0
# 213    13.0
# 85     13.0
# 44     13.0
# 43     13.0
# 215    13.0
# 87     13.0
# 214    13.0
# 62     13.0
# 92     13.0
# 73     13.0
# 94     13.0
# 96     13.0
# 208    13.0
# 137    13.0
# 70     13.0
# 68     13.0
# 105    13.0
#        ...
# 381    36.0
# 379    36.0
# 391    36.0
# 380    36.0
# 245    36.1
# 248    36.1
# 327    36.4
# 347    37.0
# 320    37.0
# 376    37.0
# 312    37.2
# 304    37.3
# 348    37.7
# 387    38.0
# 378    38.0
# 385    38.0
# 383    38.0
# 310    38.1
# 344    39.0
# 343    39.1
# 247    39.4
# 324    40.8
# 330    40.9
# 309    41.5
# 244    43.1
# 326    43.4
# 394    44.0
# 325    44.3
# 329    44.6
# 322    46.6
# Name: mpg, Length: 398, dtype: float64

# %% [markdown]
# The second lowest value is ... 10.0!

# %% [markdown]
# __Sort__ the Series __mpg__ from __high to low__ and __save the changes__ by setting the __inplace__ parameter to __True__

# %%
mpg.sort_values(ascending = False, inplace = True)

# %% [markdown]
# __First 5 elements__ of mpg

# %%
mpg.head()
# Out:
# 322    46.6
# 329    44.6
# 325    44.3
# 394    44.0
# 326    43.4
# Name: mpg, dtype: float64

# %% [markdown]
# The second highest value is ... 44.6!

# %% [markdown]
# __Sort__ the Series __mpg__ by the __Index__

# %%
mpg.sort_index(inplace = True)

# %%
mpg.head(10)
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# 5    15.0
# 6    14.0
# 7    14.0
# 8    14.0
# 9    15.0
# Name: mpg, dtype: float64

# %% [markdown]
# __Miles per Gallon__ (mpg) is transformed into __Liter per 100 Kilometer__:<br>
# __Liter per 100 Kilometer = 235.21 / mpg__<br><br>
# Series __l_per_100__ by applying the above formula __Round__ the results to __2 decimals__

# %%
l_per_100 = (235.21/mpg).round(2)

# %%
l_per_100.head()
# Out:
# 0    13.07
# 1    15.68
# 2    13.07
# 3    14.70
# 4    13.84
# Name: mpg, dtype: float64

# %% [markdown]
# The first element is ... 13.07!

# %% [markdown]
# __Summary statistics__ on __l_per_100__

# %%
l_per_100.describe()
# Out:
# count    398.000000
# mean      11.212789
# std        3.901407
# min        5.050000
# 25%        8.110000
# 50%       10.230000
# 75%       13.440000
# max       26.130000
# Name: mpg, dtype: float64

# %% [markdown]
# Average value is approx. ... 11.21!

# %% [markdown]
# Non-numerical column __"origin"__, create a __copy__ and __save__ the column

# %%
origin = cars.origin.copy()

# %%
origin.head()
# Out:
# 0    usa
# 1    usa
# 2    usa
# 3    usa
# 4    usa
# Name: origin, dtype: object

# %% [markdown]
# First 5 elements are all ... usa!

# %%
origin.describe()
# Out:
# count     398
# unique      3
# top       usa
# freq      249
# Name: origin, dtype: object

# %% [markdown]
# The most frequent value is ... usa!

# %% [markdown]
# __unique values__ in __origin__

# %%
origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %% [markdown]
# ... japan and europe!

# %% [markdown]
# __count the frequencies__ in __origin__

# %%
origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %% [markdown]
# The value europe appears ... 70 times!

# %% [markdown]
# ### Index Operations

# %%
cars = pd.read_csv("cars.csv")

# %% [markdown]
# __index__ of __cars__

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %% [markdown]
# It´s a ... RangeIndex!

# %% [markdown]
# __Set__ the __"name"__ column as the __new index__

# %%
cars.set_index("name", inplace = True)

# %% [markdown]
# __Check__ whether the new index contains __only unique values__

# %%
cars.index.is_unique
# Out:
# False

# %% [markdown]
# There are duplicate entries

# %% [markdown]
# __Frequency Counts__ of all unique values in the index

# %%
cars.index.value_counts()
# Out:
# ford pinto                          6
# vw rabbit                           5
# toyota corolla                      5
# amc matador                         5
# ford maverick                       5
# peugeot 504                         4
# toyota corona                       4
# chevrolet chevette                  4
# amc hornet                          4
# amc gremlin                         4
# chevrolet impala                    4
# chevrolet vega                      3
# ford gran torino                    3
# chevrolet chevelle malibu           3
# plymouth duster                     3
# chevrolet nova                      3
# honda civic                         3
# chevrolet caprice classic           3
# chevrolet citation                  3
# vw dasher                           3
# dodge colt                          3
# ford galaxie 500                    3
# pontiac catalina                    3
# plymouth fury iii                   3
# honda accord                        2
# ...

# %% [markdown]
# The most frequent value is ... ford pinto!

# %% [markdown]
# 36. __Set__ the __name__ of the index to __"car_model"__!

# %%
cars.index.name = "car_model"

# %%
cars.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car_model
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# car_model
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %% [markdown]
#  __Reset__ the __index__ to a RangeIndex

# %%
cars.reset_index(inplace= True)

# %%
cars.head()
# Out:
#                    car_model   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %% [markdown]
# __Column Index__

# %%
cars.columns
# Out:
# Index(['car_model', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %% [markdown]
# __Rename__ the column __Labels__ "horsepower" and "origin" to "hp" and "country"

# %%
cars.rename(columns = {"horsepower":"hp", "origin":"country"}, inplace = True)

# %%
cars.head()
# Out:
#                    car_model   mpg  cylinders  displacement     hp  weight  \
# 0  chevrolet chevelle malibu  18.0          8         307.0  130.0    3504
# 1          buick skylark 320  15.0          8         350.0  165.0    3693
# 2         plymouth satellite  18.0          8         318.0  150.0    3436
# 3              amc rebel sst  16.0          8         304.0  150.0    3433
# 4                ford torino  17.0          8         302.0  140.0    3449
#
#    acceleration  model_year country
# 0          12.0          70     usa
# 1          11.5          70     usa
# 2          11.0          70     usa
# 3          12.0          70     usa
# 4          10.5          70     usa

# %% [markdown]
# ### Sorting, Ranking & Summary Statistics

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# __Sort__ the __cars__ by the __"mpg"__ column from __high to low__

# %%
cars.sort_values(by = "mpg", ascending = False, inplace= True)

# %% [markdown]
#  __Name__ of the __most fuel efficient__ car

# %%
cars.head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %% [markdown]
# The most fuel efficient car is ... mazda glc!

# %% [markdown]
# __Sort__ the __cars__ by the __index__ from __low to high__

# %%
cars.sort_index(ascending = True, inplace= True)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# __"hp_rank"__ with the __horsepower rank__ for each car

# %%
cars["hp_rank"] = cars.horsepower.rank(method = "min", ascending = False)

# %% [markdown]
# __Sort cars__ by the __"horsepower"__ from __high to low__

# %%
cars.sort_values(by = "horsepower", ascending = False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 116  16.0          8         400.0       230.0    4278           9.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 94   13.0          8         440.0       215.0    4735          11.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 27   11.0          8         318.0       210.0    4382          13.5
# 67   11.0          8         429.0       208.0    4633          11.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 5    15.0          8         429.0       198.0    4341          10.0
# 90   12.0          8         429.0       198.0    4952          11.5
# ...

# %% [markdown]
# The __"hp_rank"__ for the car __"pontiac grand prix"__ is... 1!

# %% [markdown]
# __unique values__ in __all columns__ of the cars

# %%
cars.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            300
# hp_rank          93
# dtype: int64

# %% [markdown]
# There are ... 300 unique values in the "name" column

# %% [markdown]
#  __Select__ the __10__ cars with the __highest weights__

# %%
cars.nlargest(n = 10, columns = "weight")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 42   12.0          8         383.0       180.0    4955          11.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 104  12.0          8         400.0       167.0    4906          12.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 94   13.0          8         440.0       215.0    4735          11.0
# 28    9.0          8         304.0       193.0    4732          18.5
# 137  13.0          8         350.0       150.0    4699          14.5
#
#      model_year origin                          name  hp_rank
# 44           71    usa           pontiac safari (sw)     23.0
# 103          73    usa              chevrolet impala     46.0
# ...

# %% [markdown]
# __Summary statistics__ of cars

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year     hp_rank
# count    398.000000  398.000000  392.000000
# mean      15.568090   76.010050  192.239796
# std        2.757689    3.697627  113.441056
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000   98.500000
# 50%       15.500000   76.000000  196.500000
# ...

# %% [markdown]
# __Correlation matrix__ for the __cars__

# %%
cars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# hp_rank       0.836399  -0.827170     -0.855328   -0.928239 -0.865003
#
#               acceleration  model_year   hp_rank
# mpg               0.420289    0.579267  0.836399
# cylinders        -0.505419   -0.348746 -0.827170
# displacement     -0.543684   -0.370164 -0.855328
# horsepower       -0.689196   -0.416361 -0.928239
# weight           -0.417457   -0.306564 -0.865003
# ...

# %% [markdown]
# The factor weight shows the highest negative correlation to mpg! The lower the weight, the higher the fuel efficiency!

# %% [markdown]
# ### apply(), MultiIndex and Strings

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Calculate__ for all __numerical columns__ the __range between highest and lowest__ value

# %%
cars.iloc[:, :-2].apply(lambda x: x.max() - x.min(), axis = 0)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# model_year        12.0
# dtype: float64

# %% [markdown]
# The range for mpg is ... 37.6!

# %% [markdown]
# __MultiIndex__ for the __cars__ with the columns __"model_year"__ (outer level) and __"origin"__ (inner level)

# %%
cars.set_index(["model_year", "origin"], inplace = True)

# %% [markdown]
# __Sort__ both index levels in __ascending__ order

# %%
cars.sort_index(ascending = True, inplace = True )

# %%
cars.head()
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 70         europe  26.0          4          97.0        46.0    1835
#            europe  25.0          4         110.0        87.0    2672
#            europe  24.0          4         107.0        90.0    2430
#            europe  25.0          4         104.0        95.0    2375
#            europe  26.0          4         121.0       113.0    2234
#
#                    acceleration                  name
# model_year origin
# 70         europe          20.5  vw 1131 deluxe sedan
#            europe          17.5           peugeot 504
#            europe          14.5           audi 100 ls
#            europe          17.5              saab 99e
#            europe          12.5              bmw 2002

# %% [markdown]
# __Select__ all cars with the "model_year" __75__

# %%
cars.loc[75]
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  25.0          4          90.0        71.0    2223          16.5
# europe  29.0          4          90.0        70.0    1937          14.0
# europe  23.0          4         115.0        95.0    2694          15.0
# europe  23.0          4         120.0        88.0    2957          17.0
# europe  22.0          4         121.0        98.0    2945          14.5
# europe  25.0          4         121.0       115.0    2671          13.5
# japan   29.0          4          97.0        75.0    2171          16.0
# japan   24.0          4         134.0        96.0    2702          13.5
# japan   24.0          4         119.0        97.0    2545          17.0
# japan   33.0          4          91.0        53.0    1795          17.5
# usa     19.0          6         225.0        95.0    3264          16.0
# usa     18.0          6         250.0       105.0    3459          16.0
# ...

# %% [markdown]
# __Select__ all cars with the "model_year" __76__ from __japan__

# %%
cars.loc[(76, "japan")]
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 76         japan   33.0          4          91.0        53.0    1795
#            japan   32.0          4          85.0        70.0    1990
#            japan   28.0          4          97.0        75.0    2155
#            japan   19.0          6         156.0       108.0    2930
#
#                    acceleration            name
# model_year origin
# 76         japan           17.4     honda civic
#            japan           17.0    datsun b-210
#            japan           16.4  toyota corolla
#            japan           15.5  toyota mark ii

# %% [markdown]
# There are ... 4 cars!

# %% [markdown]
# __Select__ all cars with the "model_year" __77__ and __79__  from __japan__ only the columns __"mpg"__ and __"name"__

# %%
cars.loc[([77,79], "japan"), ["mpg", "name"]]
# Out:
#                     mpg                     name
# model_year origin
# 77         japan   31.5        honda accord cvcc
#            japan   33.5    datsun f-10 hatchback
#            japan   26.0  toyota corolla liftback
#            japan   30.0                subaru dl
#            japan   22.0               datsun 810
#            japan   21.5               mazda rx-4
# 79         japan   34.1         mazda glc deluxe
#            japan   31.8               datsun 210

# %% [markdown]
# The mpg of datsun 210 is ... 31.8!

# %% [markdown]
#  __Swap the levels__ of the MultiIndex and then __sort__ the new MultiIndex in __ascending__ order! __Reassign cars__

# %%
cars = cars.swaplevel().sort_index(ascending = True)

# %%
cars.head()
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# origin model_year
# europe 70          26.0          4          97.0        46.0    1835
#        70          25.0          4         110.0        87.0    2672
#        70          24.0          4         107.0        90.0    2430
#        70          25.0          4         104.0        95.0    2375
#        70          26.0          4         121.0       113.0    2234
#
#                    acceleration                  name
# origin model_year
# europe 70                  20.5  vw 1131 deluxe sedan
#        70                  17.5           peugeot 504
#        70                  14.5           audi 100 ls
#        70                  17.5              saab 99e
#        70                  12.5              bmw 2002

# %% [markdown]
# __Reset__ the __index__ of __cars__

# %%
cars.reset_index(inplace = True)

# %%
cars.head()
# Out:
#    origin  model_year   mpg  cylinders  displacement  horsepower  weight  \
# 0  europe          70  26.0          4          97.0        46.0    1835
# 1  europe          70  25.0          4         110.0        87.0    2672
# 2  europe          70  24.0          4         107.0        90.0    2430
# 3  europe          70  25.0          4         104.0        95.0    2375
# 4  europe          70  26.0          4         121.0       113.0    2234
#
#    acceleration                  name
# 0          20.5  vw 1131 deluxe sedan
# 1          17.5           peugeot 504
# 2          14.5           audi 100 ls
# 3          17.5              saab 99e
# 4          12.5              bmw 2002

# %% [markdown]
# __Convert__ all elements in the __origin__ column to __titlecase__

# %%
cars.origin = cars.origin.str.title()

# %%
cars.head()
# Out:
#    origin  model_year   mpg  cylinders  displacement  horsepower  weight  \
# 0  Europe          70  26.0          4          97.0        46.0    1835
# 1  Europe          70  25.0          4         110.0        87.0    2672
# 2  Europe          70  24.0          4         107.0        90.0    2430
# 3  Europe          70  25.0          4         104.0        95.0    2375
# 4  Europe          70  26.0          4         121.0       113.0    2234
#
#    acceleration                  name
# 0          20.5  vw 1131 deluxe sedan
# 1          17.5           peugeot 504
# 2          14.5           audi 100 ls
# 3          17.5              saab 99e
# 4          12.5              bmw 2002

# %% [markdown]
# __Extract the manufacturer names__ from the column __"name"__. <br>
# __Split__ the strings in the column __"name"__ on the very __first whitespace__ and __expand__ the splitted strings into __separate columns__

# %%
split = cars.name.str.split(pat = " ", n = 1, expand = True)

# %%
split.head()
# Out:
#          0                  1
# 0       vw  1131 deluxe sedan
# 1  peugeot                504
# 2     audi             100 ls
# 3     saab                99e
# 4      bmw               2002

# %% [markdown]
# __Frequency of unique values__

# %%
split[0].value_counts()
# Out:
# ford             51
# chevrolet        47
# plymouth         31
# dodge            28
# amc              28
# toyota           26
# datsun           23
# vw               22
# buick            17
# pontiac          16
# honda            13
# mazda            12
# mercury          12
# oldsmobile       10
# peugeot           8
# fiat              8
# audi              7
# volvo             6
# chrysler          6
# renault           5
# saab              4
# subaru            4
# opel              4
# mercedes-benz     3
# cadillac          2
# bmw               2
# nissan            1
# triumph           1
# ih                1
# Name: 0, dtype: int64

# %% [markdown]
# There are 51 cars from the manufacturer ... Ford!

# %% [markdown]
# __doublecheck__ the result from above

# %%
cars.name.str.contains("ford").sum()
# Out:
# 51

# %% [markdown]
# ### Filtering DataFrames

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# All elements in the column __"origin"__ whether they are __equal to "europe"__

# %%
mask1 = cars.origin == "europe"
mask1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 368    False
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# 374    False
# 375     True
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394     True
# 395    False
# 396    False
# 397    False
# Name: origin, Length: 398, dtype: bool

# %% [markdown]
# All elements in the column __"mpg"__ whether they are __smaller than 20__

# %%
mask2 = cars.mpg < 20

# %% [markdown]
# __Filter__ the cars DataFrame for __all cars from europe__

# %%
europe  = cars.loc[mask1].copy()

# %% [markdown]
# __Inspect__! What is the name of the __second__ car?

# %%
europe.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19  26.0          4          97.0        46.0    1835          20.5
# 20  25.0          4         110.0        87.0    2672          17.5
# 21  24.0          4         107.0        90.0    2430          14.5
# 22  25.0          4         104.0        95.0    2375          17.5
# 23  26.0          4         121.0       113.0    2234          12.5
#
#     model_year  origin                  name
# 19          70  europe  vw 1131 deluxe sedan
# 20          70  europe           peugeot 504
# 21          70  europe           audi 100 ls
# 22          70  europe              saab 99e
# 23          70  europe              bmw 2002

# %%
europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 19 to 394
# Data columns (total 9 columns):
# mpg             70 non-null float64
# cylinders       70 non-null int64
# displacement    70 non-null float64
# horsepower      68 non-null float64
# weight          70 non-null int64
# acceleration    70 non-null float64
# model_year      70 non-null int64
# origin          70 non-null object
# name            70 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 5.5+ KB

# %% [markdown]
# All cars __from europe with low fuel efficiency__

# %%
europe_le = cars.loc[mask1 & mask2].copy()

# %% [markdown]
# The __least efficient__ car from europe

# %%
europe_le
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 76   18.0          4         121.0       112.0    2933          14.5
# 120  19.0          4         121.0       112.0    2868          15.5
# 209  19.0          4         120.0        88.0    3270          21.9
# 211  16.5          6         168.0       120.0    3820          16.7
# 275  17.0          6         163.0       125.0    3140          13.6
# 277  16.2          6         163.0       133.0    3410          15.8
#
#      model_year  origin                name
# 76           72  europe     volvo 145e (sw)
# 120          73  europe         volvo 144ea
# 209          76  europe         peugeot 504
# 211          76  europe  mercedes-benz 280s
# 275          78  europe         volvo 264gl
# 277          78  europe       peugeot 604sl

# %% [markdown]
# The least efficient european car is ... peugeot 604sl

# %% [markdown]
# All cars with an __mpg between 10 and 15__

# %%
mpg_10_15 = cars.loc[cars.mpg.between(10,15)].copy()

# %%
mpg_10_15.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
#
#    model_year origin               name
# 1          70    usa  buick skylark 320
# 5          70    usa   ford galaxie 500
# 6          70    usa   chevrolet impala
# 7          70    usa  plymouth fury iii
# 8          70    usa   pontiac catalina

# %% [markdown]
# The __first__ car is... buick skylark 320!

# %%
mpg_10_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 1 to 224
# Data columns (total 9 columns):
# mpg             68 non-null float64
# cylinders       68 non-null int64
# displacement    68 non-null float64
# horsepower      68 non-null float64
# weight          68 non-null int64
# acceleration    68 non-null float64
# model_year      68 non-null int64
# origin          68 non-null object
# name            68 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 5.3+ KB

# %% [markdown]
# There are ... 68 cars!

# %% [markdown]
# All cars that are __not built in the years 73 and 74__, and only the columns __"mpg"__ and __"name"__!

# %%
not_73_74 = cars.loc[~cars.model_year.isin([73, 74]), ["mpg", "name"]].copy()

# %%
not_73_74.head()
# Out:
#     mpg                       name
# 0  18.0  chevrolet chevelle malibu
# 1  15.0          buick skylark 320
# 2  18.0         plymouth satellite
# 3  16.0              amc rebel sst
# 4  17.0                ford torino

# %%
not_73_74.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331 entries, 0 to 397
# Data columns (total 2 columns):
# mpg     331 non-null float64
# name    331 non-null object
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %% [markdown]
# There are ... 331 cars

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# __Drop__ the columns __"displacement"__ and __"cylinders"__ from the DataFrame cars

# %%
cars.drop(columns = ["displacement", "cylinders"], inplace = True)

# %%
cars.head()
# Out:
#     mpg  horsepower  weight  acceleration  model_year origin  \
# 0  18.0       130.0    3504          12.0          70    usa
# 1  15.0       165.0    3693          11.5          70    usa
# 2  18.0       150.0    3436          11.0          70    usa
# 3  16.0       150.0    3433          12.0          70    usa
# 4  17.0       140.0    3449          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# __Drop__ all cars from __"usa"__

# %%
cars = cars.loc[cars.origin != "usa"]

# %%
cars.head()
# Out:
#      mpg  horsepower  weight  acceleration  model_year  origin  \
# 14  24.0        95.0    2372          15.0          70   japan
# 18  27.0        88.0    2130          14.5          70   japan
# 19  26.0        46.0    1835          20.5          70  europe
# 20  25.0        87.0    2672          17.5          70  europe
# 21  24.0        90.0    2430          14.5          70  europe
#
#                      name
# 14  toyota corona mark ii
# 18           datsun pl510
# 19   vw 1131 deluxe sedan
# 20            peugeot 504
# 21            audi 100 ls

# %% [markdown]
# New column __"l_per_100km"__ to the DataFrame cars by calculating __235.21/mpg__

# %%
cars["l_per_100km"] = (235.21/cars.mpg).round(2)

# %% [markdown]
# What is the __"l_per_100km"__ value for the __audi 100 ls__?

# %%
cars.head()
# Out:
#      mpg  horsepower  weight  acceleration  model_year  origin  \
# 14  24.0        95.0    2372          15.0          70   japan
# 18  27.0        88.0    2130          14.5          70   japan
# 19  26.0        46.0    1835          20.5          70  europe
# 20  25.0        87.0    2672          17.5          70  europe
# 21  24.0        90.0    2430          14.5          70  europe
#
#                      name  l_per_100km
# 14  toyota corona mark ii         9.80
# 18           datsun pl510         8.71
# 19   vw 1131 deluxe sedan         9.05
# 20            peugeot 504         9.41
# 21            audi 100 ls         9.80

# %% [markdown]
# The "l_per_100km" value for the audi 100 ls is ... 9.80!

# %% [markdown]
# ### Manipulating elements in a DataFrame

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# All cars having an __mpg higher than 40__

# %%
high_eff = cars.loc[cars.mpg > 40].copy()

# %% [markdown]
# __Cap__ the __mpg__ for all cars in __high_eff__ to __40__

# %%
high_eff.mpg = 40

# %%
high_eff
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244   40          4          90.0        48.0    1985          21.5
# 309   40          4          98.0        76.0    2144          14.7
# 322   40          4          86.0        65.0    2110          17.9
# 324   40          4          85.0        65.0    2110          19.2
# 325   40          4          90.0        48.0    2085          21.7
# 326   40          4          90.0        48.0    2335          23.7
# 329   40          4          91.0        67.0    1850          13.8
# 330   40          4          85.0         NaN    1835          17.3
# 394   40          4          97.0        52.0    2130          24.6
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# 324          80   japan               datsun 210
# ...

# %%
# run the cell!
cars.mpg.max()
# Out:
# 46.6

# %% [markdown]
# __Cap__ all mpg values __greater than 40__ to 40

# %%
cars.loc[cars.mpg > 40, "mpg"] = 40

# %% [markdown]
# Values __greater than 40__ in the __"mpg"__ column of the __cars__

# %%
cars.mpg.max()
# Out:
# 40.0

# %% [markdown]
# ### Plotting Data with Matplotlib

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# __Lineplot__

# %%
cars.plot(subplots = True, sharex = False, figsize = (15,15))
plt.show();

# %% [markdown]
# __Histogram__ for __mpg__

# %%
cars.mpg.hist(figsize = (12,8), bins = 40)
plt.title("MPG", fontsize = 15)
plt.xlabel("mpg", fontsize = 13)
plt.ylabel("frequency", fontsize = 13)
plt.show();

# %% [markdown]
# __Scatterplot__ with __horsepower__ and __mpg__

# %%
cars.plot(kind = "scatter", x = "horsepower", y = "mpg", figsize = (12,8), c = "cylinders", marker = "x", colormap = "viridis")
plt.title("MPG vs. Horsepower", fontsize = 18)
plt.xlabel("horsepower", fontsize = 15)
plt.ylabel("mpg", fontsize = 15)
plt.show();
